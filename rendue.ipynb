# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df_alim = pd.read_csv('/content/drive/MyDrive/Epsi/Atelier composants métier/Projet/export_alimconfiance@dgal.csv', sep=';')

# %%
df_alim.shape
# Out:
# (32720, 13)

# %%
df_alim.head()
# Out:
#                   APP_Libelle_etablissement           SIRET  \
# 0                SARL AUBERGE DU DOUBLE SIX  30121048000010
# 1                MONSIEUR PHILIPPE MARIOTTE  31084873400029
# 2              NATURALIA (NATURALIA FRANCE)  30247464801894
# 3        SUPER-U (COLOMBELLES DISTRIBUTION)  30122377200031
# 4  FRANPRIX (SOC DISTRIBUTION SODISCO SARL)  33427109500013
#
#                  Adresse_2_UA Code_postal Libelle_commune Numero_inspection  \
# 0       24 PL GENERAL LECLERC       80220        GAMACHES          16793484
# 1           286 RUE DU CENTRE       74260        LES GETS          16740394
# 2  36 RUE EUGENE EICHENBERGER       92800         PUTEAUX          16611978
# 3                      RD 403       14460     COLOMBELLES          16787460
# 4        4, PLACE DU MOUSTIER       92210     SAINT CLOUD          16748988
#
#              Date_inspection APP_Libelle_activite_etablissement  \
# 0  2023-04-25T02:00:00+02:00                         Restaurant
# 1  2023-02-23T01:00:00+01:00                         Restaurant
# 2  2022-10-04T02:00:00+02:00              Alimentation générale
# 3  2023-04-20T02:00:00+02:00        Rayon boucherie-charcuterie
# 4  2023-03-08T01:00:00+01:00              Alimentation générale
#
#   Synthese_eval_sanit Agrement               geores  \
# 0        Satisfaisant      NaN  49.985274, 1.561386
# 1        Satisfaisant      NaN   46.15861, 6.677963
# 2        Satisfaisant      NaN   48.881317, 2.23746
# 3   Très satisfaisant      NaN                  NaN
# 4         A améliorer      NaN  48.844091, 2.219818
#
#                         filtre ods_type_activite
# 0                   Restaurant            Autres
# 1                   Restaurant            Autres
# 2        Alimentation générale            Autres
# 3  Rayon boucherie-charcuterie            Autres
# 4        Alimentation générale            Autres

# %%
df_alim.columns
# Out:
# Index(['APP_Libelle_etablissement', 'SIRET', 'Adresse_2_UA', 'Code_postal',
#        'Libelle_commune', 'Numero_inspection', 'Date_inspection',
#        'APP_Libelle_activite_etablissement', 'Synthese_eval_sanit', 'Agrement',
#        'geores', 'filtre', 'ods_type_activite'],
#       dtype='object')

# %%
df_alim[['filtre', 'ods_type_activite']]
# Out:
#                             filtre           ods_type_activite
# 0                       Restaurant                      Autres
# 1                       Restaurant                      Autres
# 2            Alimentation générale                      Autres
# 3      Rayon boucherie-charcuterie                      Autres
# 4            Alimentation générale                      Autres
# ...                            ...                         ...
# 32715                          NaN                   Abattoirs
# 32716                   Restaurant                      Autres
# 32717                          NaN  Viandes et produits carnés
# 32718                   Restaurant                      Autres
# 32719           Producteur fermier                      Autres
#
# [32720 rows x 2 columns]

# %%
dict_exigence = {}

# %%
df_alim['filtre'] = df_alim['filtre'].fillna('__')

# %%
df_comma_filtered = df_alim[df_alim['filtre'].str.contains(',')]

# %%
list_categories = list(set(df_comma_filtered['filtre'].values))

# %%
unique_categories = []
for cat in list_categories:
  unique_categories.extend([x for x in cat.split(',')])

set(unique_categories)
# Out:
# {'Alimentation générale',
#  'Boucherie-Charcuterie',
#  'Boulangerie-Pâtisserie',
#  'Chocolatier',
#  'Fromagerie',
#  'Glacier',
#  'Libre service',
#  'Poissonnerie',
#  'Rayon boucherie-charcuterie',
#  'Rayon fromagerie',
#  'Rayon pain/viennoiserie/pâtisserie',
#  'Rayon poissonnerie',
#  'Rayon traiteur',
#  'Traiteur'}

# %%
df_filtered = df_alim[~df_alim['filtre'].str.contains(',')]
#df_filtered = df_filtered[~df_filtered['APP_Libelle_activite_etablissement'].isin(unique_categories)]

# %%
list_df_filtered = list(df_filtered['filtre'].values)
list_df_filtered.extend(unique_categories)
list_unique_categories = list(set(list_df_filtered))

# %%
list_unique_categories.sort()
list_unique_categories
# Out:
# ['Alimentation générale',
#  'Boucherie-Charcuterie',
#  'Boulangerie-Pâtisserie',
#  'Chocolatier',
#  'Fromagerie',
#  'Glacier',
#  'Libre service',
#  'Poissonnerie',
#  'Primeur',
#  'Producteur fermier',
#  'Rayon boucherie-charcuterie',
#  'Rayon fromagerie',
#  'Rayon fruits & légumes',
#  'Rayon pain/viennoiserie/pâtisserie',
#  'Rayon poissonnerie',
#  'Rayon traiteur',
#  'Restaurant',
#  'Restauration collective',
#  'Traiteur',
#  '__']

# %%
len(set(df_alim['filtre'].values))
# Out:
# 95

# %%
len(set(df_alim['APP_Libelle_activite_etablissement'].values))
# Out:
# 149

# %%
import matplotlib.pyplot as plt

# %%
#set(df_alim['APP_Libelle_activite_etablissement'].values)

# %%
from collections import Counter
count = Counter(df_alim['APP_Libelle_activite_etablissement'])

count.most_common()
# Out:
# [('Restaurant', 11653),
#  ('Restauration collective', 6651),
#  ('Producteur fermier', 1460),
#  ('Transformation de lait ou produits laitiers', 1376),
#  ('Boucherie-Charcuterie', 1101),
#  ('Transformation de produits carnés', 1059),
#  ("Chaîne d'abattage de volaille/lagomorphe/petit gibier", 722),
#  ('Purification/Expédition de coquillages', 669),
#  ('Découpe de viande de boucherie', 661),
#  ('Boulangerie-Pâtisserie', 524),
#  ("Centre d'emballage des oeufs", 386),
#  ('Libre service,Alimentation générale', 365),
#  ('VH, VSM, préparation viandes boucherie', 354),
#  ('Libre service', 348),
#  ('Transformation de produits de la pêche', 335),
#  ('Mareyage et préparation de produits de la pêche', 316),
#  ('Entreposage de distribution de denrées alimentaires', 312),
#  ("Chaîne d'abattage d'animaux boucherie/Gibier ongulé élevage", 309),
#  ('Traiteur', 304),
#  ('Transport de denrées alimentaires', 273),
#  ('Découpe de viandes de volailles/lagomorphe', 256),
#  ('Traiteur,Boucherie-Charcuterie', 255),
#  ('Rayon boucherie-charcuterie', 237),
#  ('Poissonnerie', 216),
#  ('Métier de bouche', 199),
#  ('Rayon poissonnerie', 198),
#  ('Alimentation générale', 161),
#  ("Caves d'affinage", 155),
#  ('Commerce alimentaire', 143),
#  ('Préparation de produits composés', 97),
#  ('Autres activités de remise directe', 97),
#  ('Fromagerie', 92),
#  ('Entreposage non spécialisé de denrées alimentaires', 91),
#  ('VH, VSM, préparation viandes volailles lagomorphes', 90),
#  ('Vivier produits de la pêche', 69),
#  ('Entreposage de viande de boucherie', 67),
#  ('Rayon pain/viennoiserie/pâtisserie', 66),
#  ("Salle d'abattage à la ferme", 61),
#  ('Découpe de fromages', 58),
#  ('Pêche de production primaire', 56),
#  ('Entreposage de produits de la pêche', 47),
#  ('_', 40),
#  ('Alimentation générale,Boucherie-Charcuterie', 40),
#  ("Production d'œuf liquide d'ovoproduit et produits à base œuf", 35),
#  ('Entreposage de produits laitiers', 34),
#  ('Déshydratation de lait ou produits laitiers', 34),
#  ("Production de produits à base d'escargots", 29),
#  ('Boulangerie-Pâtisserie,Traiteur', 29),
#  ('Rayon traiteur', 28),
#  ("Production d'abats", 27),
#  ('Glacier', 27),
#  ('Rayon fromagerie', 27),
#  ('Fromagerie,Boucherie-Charcuterie', 26),
#  ("Abattage de produits de l'aquaculture", 26),
#  ('Rayon traiteur,Rayon boucherie-charcuterie', 25),
#  ('Alimentation générale,Boulangerie-Pâtisserie', 22),
#  ('Traitement du gibier sauvage', 20),
#  ('Halle à M./1ére vente/Vente en gros produits de la pêche', 19),
#  ('Découpe de gibier sauvage', 15),
#  ('Poissonnerie,Traiteur', 14),
#  ('Fromagerie,Alimentation générale', 14),
#  ('Collecte de gibier sauvage', 13),
#  ('Alimentation générale,Traiteur', 13),
#  ('Rayon fromagerie,Rayon boucherie-charcuterie', 12),
#  ('Chocolatier', 11),
#  ('Rayon poissonnerie,Rayon fromagerie,Rayon boucherie-charcuterie', 11),
#  ('Gestion administrative-Restauration collective', 10),
#  ('Entreposage de viande de volailles', 10),
#  ('Infrastructure de Marché', 10),
#  ('Fromagerie,Traiteur,Boucherie-Charcuterie', 9),
#  ('Vente en gros de viande de boucherie', 8),
#  ('Libre service,Alimentation générale,Boucherie-Charcuterie', 8),
#  ('Rayon poissonnerie,Rayon fromagerie,Rayon traiteur,Rayon boucherie-charcuterie',
#   7),
#  ('Distribution automatique', 7),
#  ('Boulangerie-Pâtisserie,Glacier', 7),
#  ('Collecte de lait', 7),
#  ('Rayon poissonnerie,Rayon fromagerie,Rayon traiteur,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   6),
#  ('Rayon poissonnerie,Rayon boucherie-charcuterie', 6),
#  ('Libre service,Rayon boucherie-charcuterie', 6),
#  ('Production de produits à base de grenouilles', 5),
#  ("Plateforme d'éclatement de produits de la pêche", 5),
#  ('Rayon traiteur,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   5),
#  ('Chocolatier,Boulangerie-Pâtisserie', 5),
#  ('Fromagerie,Libre service,Alimentation générale', 4),
#  ('Production de collagène, de gélatine ou de PHR', 4),
#  ('Rayon fromagerie,Rayon traiteur,Rayon boucherie-charcuterie', 4),
#  ('Fromagerie,Alimentation générale,Boucherie-Charcuterie', 4),
#  ('Responsable de restauration collective', 4),
#  ('Alimentation générale,Poissonnerie', 4),
#  ("Découpe de gros gibier d'élevage", 4),
#  ('Libre service,Rayon poissonnerie,Rayon fromagerie,Rayon boucherie-charcuterie',
#   4),
#  ('Libre service,Rayon poissonnerie,Rayon fromagerie,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   3),
#  ('Chocolatier,Boulangerie-Pâtisserie,Glacier', 3),
#  ('Poissonnerie,Traiteur,Boucherie-Charcuterie', 3),
#  ('Fromagerie,Libre service,Alimentation générale,Boucherie-Charcuterie', 3),
#  ('Primeur', 2),
#  ('Découpe de produits de charcuterie', 2),
#  ('Collecte et transformation de miel', 2),
#  ('Libre service,Alimentation générale,Traiteur', 2),
#  ('Libre service,Rayon poissonnerie,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   2),
#  ('Libre service,Rayon poissonnerie,Rayon fromagerie,Rayon traiteur,Rayon boucherie-charcuterie',
#   2),
#  ('Alimentation générale,Glacier', 2),
#  ('Libre service,Alimentation générale,Boulangerie-Pâtisserie', 2),
#  ('Fromagerie,Traiteur', 2),
#  ('Poissonnerie,Boucherie-Charcuterie', 2),
#  ("Collecteur d'oeufs", 2),
#  ('Libre service,Rayon fromagerie,Rayon traiteur,Rayon boucherie-charcuterie',
#   2),
#  ('Rayon poissonnerie,Rayon traiteur', 2),
#  ('Rayon poissonnerie,Rayon traiteur,Rayon boucherie-charcuterie', 2),
#  ('Rayon poissonnerie,Rayon traiteur,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   2),
#  ('Rayon poissonnerie,Rayon fromagerie', 2),
#  ('Libre service,Rayon poissonnerie,Rayon fromagerie,Rayon traiteur,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   2),
#  ('Boulangerie-Pâtisserie,Boucherie-Charcuterie', 2),
#  ('Libre service,Rayon traiteur', 2),
#  ('Fromagerie,Libre service,Alimentation générale,Boulangerie-Pâtisserie,Boucherie-Charcuterie',
#   2),
#  ('Libre service,Boucherie-Charcuterie', 2),
#  ('Rayon pain-viennoiserie-pâtisserie', 1),
#  ('Rayon fruits & légumes', 1),
#  ('Fromagerie,Libre service,Alimentation générale,Traiteur', 1),
#  ('Libre service,Alimentation générale,Boulangerie-Pâtisserie,Boucherie-Charcuterie',
#   1),
#  ('Fromagerie,Chocolatier', 1),
#  ('Alimentation générale,Boulangerie-Pâtisserie,Glacier,Poissonnerie,Boucherie-Charcuterie',
#   1),
#  ('Fromagerie,Libre service,Alimentation générale,Glacier,Boucherie-Charcuterie',
#   1),
#  ('Rayon fromagerie,Alimentation générale,Rayon boucherie-charcuterie', 1),
#  ('Fromagerie,Libre service,Alimentation générale,Poissonnerie,Traiteur,Boucherie-Charcuterie',
#   1),
#  ('Alimentation générale,Boulangerie-Pâtisserie,Traiteur', 1),
#  ('Alimentation générale,Traiteur,Boucherie-Charcuterie', 1),
#  ('Rayon poissonnerie,Rayon fromagerie,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   1),
#  ('Libre service,Rayon pain/viennoiserie/pâtisserie', 1),
#  ('Libre service,Alimentation générale,Poissonnerie,Boucherie-Charcuterie', 1),
#  ('Libre service,Rayon poissonnerie', 1),
#  ('Rayon fromagerie,Rayon traiteur,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   1),
#  ('Libre service,Rayon traiteur,Rayon boucherie-charcuterie', 1),
#  ('Fromagerie,Alimentation générale,Traiteur,Boucherie-Charcuterie', 1),
#  ('Vente en gros de viande de volailles', 1),
#  ('Fromagerie,Alimentation générale,Boulangerie-Pâtisserie,Boucherie-Charcuterie',
#   1),
#  ('Fromagerie,Glacier', 1),
#  ('Libre service,Rayon poissonnerie,Rayon fromagerie,Rayon traiteur,Rayon pain/viennoiserie/pâtisserie',
#   1),
#  ('Alimentation générale,Rayon pain/viennoiserie/pâtisserie', 1),
#  ('Rayon poissonnerie,Alimentation générale', 1),
#  ('Elevage de caprins', 1),
#  ('Libre service,Alimentation générale,Traiteur,Boucherie-Charcuterie', 1),
#  ('Fromagerie,Libre service,Alimentation générale,Traiteur,Boucherie-Charcuterie',
#   1),
#  ('Libre service,Rayon fromagerie,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   1),
#  ('Fromagerie,Alimentation générale,Glacier,Traiteur,Boucherie-Charcuterie',
#   1),
#  ('Elevage de bovins', 1),
#  ('Rayon fromagerie,Rayon pain/viennoiserie/pâtisserie,Rayon boucherie-charcuterie',
#   1),
#  ('Libre service,Rayon poissonnerie,Rayon traiteur,Rayon boucherie-charcuterie',
#   1),
#  ('Fromagerie,Alimentation générale,Boulangerie-Pâtisserie,Traiteur', 1)]

# %%
count.most_common()[0][1]
# Out:
# 11653

# %%
list_etab = [x[0] for x in count.most_common() if x[1] > 100]

# %%
df_alim = df_alim[df_alim['APP_Libelle_activite_etablissement'].isin(list_etab)].reset_index()

# %%
df_alim.to_csv('/content/drive/MyDrive/Epsi/Atelier composants métier/Projet/data_formated.csv', index=False)

# %%
df_alim.columns
# Out:
# Index(['index', 'APP_Libelle_etablissement', 'SIRET', 'Adresse_2_UA',
#        'Code_postal', 'Libelle_commune', 'Numero_inspection',
#        'Date_inspection', 'APP_Libelle_activite_etablissement',
#        'Synthese_eval_sanit', 'Agrement', 'geores', 'filtre',
#        'ods_type_activite'],
#       dtype='object')

# %%
df_alim.dtypes
# Out:
# index                                  int64
# APP_Libelle_etablissement             object
# SIRET                                 object
# Adresse_2_UA                          object
# Code_postal                           object
# Libelle_commune                       object
# Numero_inspection                     object
# Date_inspection                       object
# APP_Libelle_activite_etablissement    object
# Synthese_eval_sanit                   object
# Agrement                              object
# geores                                object
# filtre                                object
# ods_type_activite                     object
# dtype: object

# %%
from datetime import datetime
import pytz

def convert_to_timestamp(dt):
  date_time_str = dt

  date_time_obj = datetime.fromisoformat(date_time_str)

  timestamp = date_time_obj.timestamp()

  return timestamp

# %%
#df_alim['Date_inspection'] = df_alim.apply

# %%
list_date = list(df_alim['Date_inspection'].values)

# %%
timestamps = []

for dt in list_date:
  timestamp = convert_to_timestamp(dt)
  timestamps.append(timestamp)

# %%
df_alim['Date_inspection_timestamp'] = timestamps

# %%
df_alim.Date_inspection_timestamp = df_alim.Date_inspection_timestamp.astype(int)

# %%
#Labelisation des valeurs

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# Encoder la chaîne de caractère
df_alim['Synthese_eval_sanit'] = label_encoder.fit_transform(df_alim['Synthese_eval_sanit'])

# %%
df_alim['APP_Libelle_activite_etablissement'] = label_encoder.fit_transform(df_alim['APP_Libelle_activite_etablissement'])
df_alim['Libelle_commune'] = label_encoder.fit_transform(df_alim['Libelle_commune'])

# %%
X = df_alim[['APP_Libelle_activite_etablissement','Libelle_commune', 'Date_inspection_timestamp']]
y = df_alim[['Synthese_eval_sanit']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
#Division de notre jeu de données en jeu d'entraînement et de test
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

from sklearn.ensemble import RandomForestClassifier

#Utilisation du Random Forest Classifier pour de la classification
rf_model = RandomForestClassifier(random_state = 100)


rf_model.fit(train_X, train_y)

#On test les performances de notre modèle avec les données de test
results_predicted = rf_model.predict(val_X)

#Validation du modèle
print("Accuracy:",round(accuracy_score(val_y, results_predicted),2))
print("Precision:",round(precision_score(val_y, results_predicted, average='weighted'),2))
print("Recall:",round(recall_score(val_y, results_predicted, average='weighted'),2))
print("F1:",round(f1_score(val_y, results_predicted, average='weighted'),2))
# Out:
# <ipython-input-28-911538fca217>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_model.fit(train_X, train_y)
# Accuracy: 0.56
# Precision: 0.54
# Recall: 0.56
# F1: 0.55
